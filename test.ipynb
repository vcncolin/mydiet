# %%
import pandas as pd

# %%
df = pd.read_csv('data_ciqual.csv')

# %%
df.head()
# Out:
#                                              Aliment EnergieUE (kcal/100g)  \
# 0  \tSalade César au poulet (salade verte, fromag...                142,04
# 1                         Abat, cuit (aliment moyen)                164,30
# 2                                          Abondance                392,80
# 3         Abricot au sirop léger, appertisé, égoutté                 63,06
# 4     Abricot au sirop léger, appertisé, non égoutté                 58,35
#
#   Protéines (g/100g) Eau (g/100g) Glucides (g/100g) Lipides (g/100g)  \
# 0               8,13         71,8              4,88               10
# 1               24,9         64,7              2,72             5,98
# 2               27,1         37,2                 0             31,6
# 3               0,94           83              13,7              0,5
# 4               0,49         83,5                14            0,043
#
#   Sucres (g/100g) Amidon (g/100g) Fibres alimentaires (g/100g)  \
# ...

# %%
df.head()
# Out:
#                                              Aliment EnergieUE (kcal/100g)  \
# 0  \tSalade César au poulet (salade verte, fromag...                142,04
# 1                         Abat, cuit (aliment moyen)                164,30
# 2                                          Abondance                392,80
# 3         Abricot au sirop léger, appertisé, égoutté                 63,06
# 4     Abricot au sirop léger, appertisé, non égoutté                 58,35
#
#   Protéines (g/100g) Eau (g/100g) Glucides (g/100g) Lipides (g/100g)  \
# 0               8,13         71,8              4,88               10
# 1               24,9         64,7              2,72             5,98
# 2               27,1         37,2                 0             31,6
# 3               0,94           83              13,7              0,5
# 4               0,49         83,5                14            0,043
#
#   Sucres (g/100g) Amidon (g/100g) Fibres alimentaires (g/100g)  \
# ...

# %%
type(df.iloc[3,4])
# Out:
# str

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2835 entries, 0 to 2834
# Data columns (total 58 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Aliment                                               2835 non-null   object
#  1   EnergieUE (kcal/100g)                                 2835 non-null   object
#  2   Protéines (g/100g)                                    2834 non-null   object
#  3   Eau (g/100g)                                          2797 non-null   object
#  4   Glucides (g/100g)                                     2833 non-null   object
#  5   Lipides (g/100g)                                      2833 non-null   object
#  6   Sucres (g/100g)                                       2820 non-null   object
#  7   Amidon (g/100g)                                       2761 non-null   object
# ...

# %%
df_filtered = df.iloc[:,1:6].apply(lambda x: x.str.replace(',','.'))
df_filtered = df_filtered.apply(pd.to_numeric, errors='coerce')

# %%
type(df_filtered.iloc[0,3])
# Out:
# numpy.float64

# %%
df_filtered.fillna(0, inplace=True)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2835 entries, 0 to 2834
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EnergieUE (kcal/100g)  2835 non-null   float64
#  1   Protéines (g/100g)     2835 non-null   float64
#  2   Eau (g/100g)           2835 non-null   float64
#  3   Glucides (g/100g)      2835 non-null   float64
#  4   Lipides (g/100g)       2835 non-null   float64
# dtypes: float64(5)
# memory usage: 110.9 KB

# %%
df.iloc[:,0]
# Out:
# 0       \tSalade César au poulet (salade verte, fromag...
# 1                              Abat, cuit (aliment moyen)
# 2                                               Abondance
# 3              Abricot au sirop léger, appertisé, égoutté
# 4          Abricot au sirop léger, appertisé, non égoutté
#                               ...
# 2830                       Potage Svtlesses Légumes Verts
# 2831                                    Quiche Lorraine U
# 2832                                      Fruidor Omega 3
# 2833                                 Tuiles aux amandes U
# 2834                                        Pain ciabatta
# Name: Aliment, Length: 2835, dtype: object

# %%
df_new = pd.concat([df.iloc[:,0],df_filtered], axis=1)

# %%
df_new.head()
# Out:
#                                              Aliment  EnergieUE (kcal/100g)  \
# 0  \tSalade César au poulet (salade verte, fromag...                 142.04
# 1                         Abat, cuit (aliment moyen)                 164.30
# 2                                          Abondance                 392.80
# 3         Abricot au sirop léger, appertisé, égoutté                  63.06
# 4     Abricot au sirop léger, appertisé, non égoutté                  58.35
#
#    Protéines (g/100g)  Eau (g/100g)  Glucides (g/100g)  Lipides (g/100g)
# 0                8.13          71.8               4.88            10.000
# 1               24.90          64.7               2.72             5.980
# 2               27.10          37.2               0.00            31.600
# 3                0.94          83.0              13.70             0.500
# 4                0.49          83.5              14.00             0.043

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2835 entries, 0 to 2834
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Aliment                2835 non-null   object
#  1   EnergieUE (kcal/100g)  2835 non-null   float64
#  2   Protéines (g/100g)     2835 non-null   float64
#  3   Eau (g/100g)           2835 non-null   float64
#  4   Glucides (g/100g)      2835 non-null   float64
#  5   Lipides (g/100g)       2835 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 133.0+ KB

# %%
df_new.to_csv('data_ciqual_filtered.csv', index=False)
